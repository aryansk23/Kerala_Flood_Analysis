# %% [markdown]
# <center><h1>KERALA FLOOD ANALYSIS</h1><center/>

# %% [markdown]
# ## Overview
#
# The Kerala Flood Analysis is a comprehensive study aimed at understanding rain patterns in Kerala from 1901 to 2018. This analysis focuses on extracting actionable insights to enhance flood due to the rainfall.
#
# #

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Aryansk Kumar\Downloads\kerala.csv")

# %%
data
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %% [markdown]
# ### Checking fo error values

# %%
data.isnull().sum()
# Out:
# SUBDIVISION         0
# YEAR                0
# JAN                 0
# FEB                 0
# MAR                 0
# APR                 0
# MAY                 0
# JUN                 0
# JUL                 0
# AUG                 0
# SEP                 0
# OCT                 0
# NOV                 0
# DEC                 0
#  ANNUAL RAINFALL    0
# FLOODS              0
# dtype: int64

# %% [markdown]
# #### There are neither Null nor error values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBDIVISION       118 non-null    object
#  1   YEAR              118 non-null    int64
#  2   JAN               118 non-null    float64
#  3   FEB               118 non-null    float64
#  4   MAR               118 non-null    float64
#  5   APR               118 non-null    float64
#  6   MAY               118 non-null    float64
#  7   JUN               118 non-null    float64
#  8   JUL               118 non-null    float64
#  9   AUG               118 non-null    float64
#  10  SEP               118 non-null    float64
#  11  OCT               118 non-null    float64
#  12  NOV               118 non-null    float64
#  13  DEC               118 non-null    float64
#  14   ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS            118 non-null    object
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', ' ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
data['FLOODS'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
data['SUBDIVISION'].unique()
# Out:
# array(['KERALA', 'KERALA '], dtype=object)

# %% [markdown]
# #### There was an error while using one of the colum names

# %%
print(data.columns)
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', ' ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()

# %% [markdown]
# #### Removed the error of the column name and can be used to plot the bar graph

# %%
plt.figure(figsize = (12,6))
plt.title('Annual rainfall by year')
plt.xlabel('Year')
plt.ylabel('Annual Rainfall')
plt.bar(data['YEAR'], data['ANNUAL RAINFALL'], color='skyblue')
# Out:
# <BarContainer object of 118 artists>

# %% [markdown]
# ### 2018 rainfall in Kerala was the highest in a long time, the highest overall in any specific year

# %%
a = df[df['YEAR']==2018].squeeze()
months = ['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']
plt.figure(figsize =(10,5))
plt.bar(months,a[months],color = 'yellow', edgecolor = 'black')
plt.title('Rainfall of each month in 2018')
plt.xlabel('Months')
plt.ylabel('Rainfall received')
plt.show()

# %% [markdown]
# ### August 2018 witnessed the highest rainfall in Kerala, leading to the devastating floods that impacted the state

# %%
plt.figure(figsize = (12,5))
df['FLOODS'].value_counts().plot(kind = 'pie',colors = ['#03fcc6','#fc0373'], autopct = '%1.1f%%', startangle = 90)
plt.title('Flood Occurred')
plt.show()

# %% [markdown]
# ### The total percentage of flood from the year 1901 to 2018 was 50.8%

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = df, x = 'FLOODS', y = ' ANNUAL RAINFALL', palette = 'mako')
plt.title('Rainfall received anually during flood and non flood years')
plt.show()
# Out:
# C:\Users\Aryansk Kumar\AppData\Local\Temp\ipykernel_20376\3670585297.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = df, x = 'FLOODS', y = ' ANNUAL RAINFALL', palette = 'mako')

# %% [markdown]
# ### when there is an annual rainfall above 3300 it is likely to be flood

# %%
monthly_avg = df[['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']].mean()
plt.figure(figsize=(12,6))
sns.barplot (x = monthly_avg.index, y =monthly_avg.values, color = 'cyan')
plt.title('Average monthly rainfall in Kerala (1901 - 2018)' , fontsize = 16)
plt.xlabel('Month')
plt.ylabel('Average rainfall (mm)')
plt.show()

# %% [markdown]
# ### July has the highest average rainfall from the year 1901 to 2018

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data = df, x = 'YEAR', y = 'JUN', color = 'orchid', marker = 'D')
plt.title('July rainfall trend over the years in Kerala', fontsize = 16)
plt.xlabel('Year')
plt.ylabel('Rainfall in June(mm)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### The graph shows the up's and down's of the rainfall in July

# %%
df['Decade'] = (df['YEAR'] // 10) * 10
plt.figure(figsize=(11,6))
custom_palette = ['slateblue', 'grey']
sns.countplot(x ='Decade',hue ='FLOODS', data = df, palette = custom_palette)
plt.title('Flood occurrences by decade', fontsize = 16)
plt.xlabel('Decade')
plt.ylabel('Count')
plt.legend(title = 'Floods')
plt.show()

# %% [markdown]
# ### The graph shows the flood occurrences in a period of 10 years from 1900 to 2010
# ### 1980 to 1990 had the least flood year

# %%
df['Monsoon_Rainfall'] = df[['JUN', 'JUL', 'AUG', 'SEP']].sum(axis = 1)
df['Non_Monsoon_Rainfall'] = df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'OCT', 'NOV', 'DEC']].sum(axis = 1)

# %%
plt.figure(figsize = (30,15))
df[['YEAR', 'Monsoon_Rainfall', 'Non_Monsoon_Rainfall']].set_index('YEAR').plot(kind = 'line', color=['slateblue', 'darkkhaki'])
plt.title('Monsoon vs Non-Monsoon Rainfall in Kerala', fontsize = 16)
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### The plot shows the monsoon and non-monsoon seosons
# #

# %% [markdown]
# ## CONCLUSION ;

# %% [markdown]
#  • There were no Null and error values in the data
#
#  • 2018 rainfall was the highest tin any specific year from 1901
#
#  • the highest raifall in 2018 was occurred in August leading to flood disaster
#
#  • The total percentage of flood from the year 1901 to 2018 was 50.8%
#
#  • July has the highest average rainfall from the year 1901 to 2018
